# %%
import csv
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from scipy.stats import zscore

# %%
#data = []
#with open('2019.csv', 'r') as mycsv:
#    csvku=csv.DictReader(mycsv, delimiter=";")
    # list(csv.reader(mycsv, delimiter=","))

#    for i in csvku:
#        data.append(dict(i))
#print(data)


df = pd.read_csv('2019.csv')
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
### mean, median, Q1, Q2,Q3,  Standard Deviation
df.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
# Mode
df.mode()
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 0               1       Afghanistan  5.208            0.96           1.465
# 1               2           Albania    NaN             NaN             NaN
# 2               3           Algeria    NaN             NaN             NaN
# 3               4         Argentina    NaN             NaN             NaN
# 4               5           Armenia    NaN             NaN             NaN
# ..            ...               ...    ...             ...             ...
# 151           152         Venezuela    NaN             NaN             NaN
# 152           153           Vietnam    NaN             NaN             NaN
# 153           154             Yemen    NaN             NaN             NaN
# 154           155            Zambia    NaN             NaN             NaN
# 155           156          Zimbabwe    NaN             NaN             NaN
#
# ...

# %%
## IQR
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# Overall rank                    77.50000
# Score                            1.64000
# GDP per capita                   0.62975
# Social support                   0.39675
# Healthy life expectancy          0.33400
# Freedom to make life choices     0.19925
# Generosity                       0.13950
# Perceptions of corruption        0.09425
# dtype: float64

# %%
### Variance
df.var()
# Out:
# Overall rank                    2041.000000
# Score                              1.239036
# GDP per capita                     0.158714
# Social support                     0.089515
# Healthy life expectancy            0.058624
# Freedom to make life choices       0.020532
# Generosity                         0.009073
# Perceptions of corruption          0.008937
# dtype: float64

# %%
### Range Score
top = df['Score'].max()
bot = df['Score'].min()
rangee = top - bot
rangee
# Out:
# 4.916

# %%
### Range GDP
top = df['GDP per capita'].max()
bot = df['GDP per capita'].min()
rangee = top - bot
rangee
# Out:
# 1.6840000000000002

# %%
### Range social support
top = df['Social support'].max()
bot = df['Social support'].min()
rangee = top - bot
rangee
# Out:
# 1.624

# %%
### Range healthy life expectancy
top = df['Healthy life expectancy'].max()
bot = df['Healthy life expectancy'].min()
rangee = top - bot
rangee
# Out:
# 1.141

# %%
### Range freedom to make life choices
top = df['Freedom to make life choices'].max()
bot = df['Freedom to make life choices'].min()
rangee = top - bot
rangee
# Out:
# 0.631

# %%
### Range generosity
top = df['Generosity'].max()
bot = df['Generosity'].min()
rangee = top - bot
rangee
# Out:
# 0.5660000000000001

# %%
### Range perceptions of corruption
top = df['Perceptions of corruption'].max()
bot = df['Perceptions of corruption'].min()
rangee = top - bot
rangee
# Out:
# 0.45299999999999996

# %%
scoreZ = df[['Score']].apply(zscore)

scoreZ
# Out:
#         Score
# 0    2.128711
# 1    1.976397
# 2    1.934938
# 3    1.880862
# 4    1.875454
# ..        ...
# 151 -1.868418
# 152 -1.961248
# 153 -1.986484
# 154 -2.094636
# 155 -2.301928
#
# [156 rows x 1 columns]

# %%
scoreZ = df[['GDP per capita']].apply(zscore)

scoreZ
# Out:
#      GDP per capita
# 0          1.095042
# 1          1.203324
# 2          1.467734
# 3          1.195769
# 4          1.236060
# ..              ...
# 151       -1.375303
# 152       -1.080675
# 153       -1.397967
# 154       -2.213861
# 155       -1.508767
#
# [156 rows x 1 columns]

# %%
scoreZ = df[['Social support']].apply(zscore)

scoreZ
# Out:
#      Social support
# 0          1.268098
# 1          1.221154
# 2          1.251332
# 3          1.392163
# 4          1.050146
# ..              ...
# 151       -1.669224
# 152       -1.085783
# 153       -2.319726
# 154       -4.053282
# 155       -2.125246
#
# [156 rows x 1 columns]

# %%
scoreZ = df[['Healthy life expectancy']].apply(zscore)

scoreZ
# Out:
#      Healthy life expectancy
# 0                   1.080422
# 1                   1.121857
# 2                   1.254446
# 3                   1.246159
# 4                   1.134287
# ..                       ...
# 151                -0.460929
# 152                -0.937421
# 153                -1.509213
# 154                -2.569928
# 155                -1.782678
#
# [156 rows x 1 columns]

# %%
scoreZ = df[['Freedom to make life choices']].apply(zscore)

scoreZ
# Out:
#      Freedom to make life choices
# 0                        1.424282
# 1                        1.396277
# 2                        1.473292
# 3                        1.389276
# 4                        1.151229
# ..                            ...
# 151                      1.137227
# 152                      0.171040
# 153                     -2.748526
# 154                     -1.173221
# 155                     -2.678512
#
# [156 rows x 1 columns]

# %%
scoreZ = df[['Generosity']].apply(zscore)

scoreZ
# Out:
#      Generosity
# 0     -0.335404
# 1      0.707265
# 2      0.907373
# 3      1.781530
# 4      1.444506
# ..          ...
# 151    0.338645
# 152    0.960033
# 153   -0.282744
# 154    0.528221
# 155    0.180664
#
# [156 rows x 1 columns]

# %%
scoreZ = df[['Perceptions of corruption']].apply(zscore)

scoreZ
# Out:
#      Perceptions of corruption
# 0                     2.996757
# 1                     3.177158
# 2                     2.444941
# 3                     0.078500
# 4                     1.988632
# ..                         ...
# 151                   3.187770
# 152                   0.386244
# 153                  -0.908401
# 154                  -0.802283
# 155                  -0.208019
#
# [156 rows x 1 columns]
